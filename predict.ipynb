# %%
import numpy as np
import pandas as pd

# %%
# train_path="/home/u131168/mh_one_api/data/train.csv"
ftrain_path="/home/u131168/mh_shell/data/full_traind.csv"
full_data_path="/home/u131168/mh_shell/data/datafinal.csv"
# test_path="/home/u131168/mh_one_api/data/test.csv"
# submission_path="/home/u131168/mh_one_api/data/submission.csv"

# train_data=pd.read_csv(train_path)
ftrain_data=pd.read_csv(ftrain_path)
full_data=pd.read_csv(full_data_path)

# test_data=pd.read_csv(test_path)
# train_data=full_data[full_data[col_cc]!=""]
test_data=full_data[full_data[col_cc]==""]
# submission_data=pd.read_csv(submission_path)

# %%
# story=ftrain_data.iloc[0,0]
# question=ftrain_data.iloc[0,1]
# ftrain_data.iloc[:15]

# ftrain_data.iloc[:,2].to_csv("/home/u131168/mh_one_api/data/train_split/train_output.csv",)

# %%
# !pip install bitsandbytes
# !pip install accelerate
# !pip install scipy
# !pip install transformers
# !pip install peft
from peft import AutoPeftModelForSeq2SeqLM
from transformers import AutoTokenizer
import torch
model_path="/home/u131168/mh_one_api/model/ft_models/flan-t5-xl_peft_finetuned_model/checkpoint-36000"
# model_path="/home/u131168/mh_one_api/model/ft_models/flan-t5-xl_peft_ss/checkpoint-7000"

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-xl")
custom_model = AutoPeftModelForSeq2SeqLM.from_pretrained(model_path, )
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# Traceback (most recent call last):
#   File "/opt/miniconda/bin/pip", line 11, in <module>
#     sys.exit(main())
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# Traceback (most recent call last):
#   File "/opt/miniconda/bin/pip", line 11, in <module>
#     sys.exit(main())
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# Traceback (most recent call last):
#   File "/opt/miniconda/bin/pip", line 11, in <module>
#     sys.exit(main())
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# Traceback (most recent call last):
#   File "/opt/miniconda/bin/pip", line 11, in <module>
#     sys.exit(main())
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 345, in run
#     session = self.get_default_session(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 98, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# Traceback (most recent call last):
#   File "/opt/miniconda/bin/pip", line 11, in <module>
#     sys.exit(main())
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 70, in main
#     return command.main(cmd_args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 216, in _main
#     self.handle_pip_version_check(options)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 179, in handle_pip_version_check
#     session = self._build_session(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 125, in _build_session
#     session = PipSession(
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 343, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/network/session.py", line 175, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 75, in get_default_environment
#     return select_backend().Environment.default()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/__init__.py", line 63, in select_backend
#     from . import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_internal/metadata/pkg_resources.py", line 8, in <module>
#     from pip._vendor import pkg_resources
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3252, in <module>
#     def _initialize_master_working_set():
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3235, in _call_aside
#     f(*args, **kwargs)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 3264, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 574, in _build_master
#     ws = cls()
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2065, in find_on_path
#     for dist in factory(fullpath):
#   File "/opt/miniconda/lib/python3.10/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2127, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# PermissionError: [Errno 13] Permission denied: '/opt/miniconda/lib/python3.10/site-packages/webcolors-1.13.dist-info'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/u131168/mh_one_api/model/predict.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell://tunnel%2Bmh_one_api/home/u131168/mh_one_api/model/predict.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> get_ipython().system('pip install transformers')
#       <a href='vscode-notebook-cell://tunnel%2Bmh_one_api/home/u131168/mh_one_api/model/predict.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> get_ipython().system('pip install peft')
# ----> <a href='vscode-notebook-cell://tunnel%2Bmh_one_api/home/u131168/mh_one_api/model/predict.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> from peft import AutoPeftModelForSeq2SeqLM
#       <a href='vscode-notebook-cell://tunnel%2Bmh_one_api/home/u131168/mh_one_api/model/predict.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from transformers import AutoTokenizer
#       <a href='vscode-notebook-cell://tunnel%2Bmh_one_api/home/u131168/mh_one_api/model/predict.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> import torch
#
# File ~/.local/lib/python3.10/site-packages/peft/__init__.py:22
#       1 # flake8: noqa
#       2 # There's no way to ignore "F401 '...' imported but unused" warnings in this
#       3 # module, but to preserve other warnings. So, don't check this module at all.
#    (...)
#      17 # See the License for the specific language governing permissions and
#      18 # limitations under the License.
#      20 __version__ = "0.5.0"
# ---> 22 from .auto import (
#      23     AutoPeftModel,
#      24     AutoPeftModelForCausalLM,
#      25     AutoPeftModelForSequenceClassification,
#      26     AutoPeftModelForSeq2SeqLM,
#      27     AutoPeftModelForTokenClassification,
#      28     AutoPeftModelForQuestionAnswering,
#      29     AutoPeftModelForFeatureExtraction,
#      30 )
#      31 from .mapping import (
#      32     MODEL_TYPE_TO_PEFT_MODEL_MAPPING,
#      33     PEFT_TYPE_TO_CONFIG_MAPPING,
#    (...)
#      36     inject_adapter_in_model,
#      37 )
#      38 from .peft_model import (
#      39     PeftModel,
#      40     PeftModelForCausalLM,
#    (...)
#      45     PeftModelForFeatureExtraction,
#      46 )
#
# File ~/.local/lib/python3.10/site-packages/peft/auto.py:21
#      18 import importlib
#      19 from typing import Optional
# ---> 21 from transformers import (
#      22     AutoModel,
#      23     AutoModelForCausalLM,
#      24     AutoModelForQuestionAnswering,
#      25     AutoModelForSeq2SeqLM,
#      26     AutoModelForSequenceClassification,
#      27     AutoModelForTokenClassification,
#      28 )
#      30 from .config import PeftConfig
#      31 from .mapping import MODEL_TYPE_TO_PEFT_MODEL_MAPPING
#
# ModuleNotFoundError: No module named 'transformers'

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
model_path="google/flan-t5-xl"
tokenizer = AutoTokenizer.from_pretrained(model_path)

ft5_model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# import torch
# prompt = "Today I believe we can finally"
# prompt = [["Please answer to the following question."," Who is going to be the next john wick d'or?"], ]
# # print(question,story)
# prompt=[[story,question]]
# input_ids = tokenizer(prompt, return_tensors="pt").input_ids
# # sample up to 30 tokens
# torch.manual_seed(0)  # doctest: +IGNORE_RESULT
# outputs = custom_model.generate(input_ids=input_ids, do_sample=True, max_length=30)

# pred_custom=tokenizer.batch_decode(outputs, skip_special_tokens=True,clean_up_tokenization_spaces=True)
# # ['Today I believe we can finally get rid of discrimination," said Rep. Mark Pocan (D-Wis.).\n\n"Just look at the']

# %%
from pprint import pprint

# p_count=50
psi,pei=50,100
prompts = ftrain_data.loc[psi:pei,['input','instruction']].values.tolist()
t_prompts=[]
for p in prompts:
    context=str(p[0]).replace(r"\n",'.')
    question=p[1]
    t_prompts+=[f"paragraph: {context}\n\n Answer the following question from the above paragraph: {question}"]
    # t_prompts+=[f"input: {context}\n\ninstruction: {question}"]

prompts=t_prompts
# prompts = ftrain_data.loc[:p_count,['input','instruction']].values.tolist()
# pprint(prompts)

# %%
res=[]

# %%
input_ids = tokenizer(prompts, return_tensors="pt" ,padding=True,truncation=True, max_length=512).input_ids
# sample up to 30 tokens
torch.manual_seed(0)  # doctest: +IGNORE_RESULT
outputs = custom_model.generate(input_ids=input_ids, do_sample=True, max_length=20)
pred_custom=tokenizer.batch_decode(outputs, skip_special_tokens=True)

# %%
import math
input_ids = tokenizer(prompts, return_tensors="pt" ,padding=True,truncation=True, max_length=512).input_ids
# input_ids=[input_ids]
# sample up to 30 tokens
torch.manual_seed(0)  # doctest: +IGNORE_RESULT
outputs = ft5_model.generate(input_ids=input_ids, do_sample=True, max_length=20,)
# print(sum(list(sum(outputs.scores))))
pred_ft5=tokenizer.batch_decode(outputs, skip_special_tokens=True,)
# pprint(prompts[5])
pred_ft5
# Out:
# ['Grief',
#  'i.',
#  'December 17',
#  'To ask something to his grandmother',
#  'he was composed',
#  'it was fun',
#  'Madison Square Garden',
#  'Lightfoot',
#  'leave',
#  'i.',
#  'CSKA Moscow',
#  'Germanic',
#  'Grand Cayman, Cayman Brac and Little Cayman',
#  'Shahadah',
#  'What the time was?',
#  'Founded in 1565 by the Portuguese,',
#  '3',
#  '(ii)',
#  'irremediable',
#  'Zahra Clare Baker',
#  'no',
#  'South Waziristan province',
#  'the Secretary of State',
#  'Simón Bolvar',
#  'Josiah Graham,',
#  'Finland',
#  'Knights of the Bath',
#  'Tom to look past the fountain',
#  'Whoa!',
#  'Vancouver is consistently named as one of the top five worldwide cities for livability and quality of',
#  'none are known to be related',
#  'A).',
#  'The searchlight',
#  'He is devastated and horrified by the death of the teen',
#  'yes',
#  'I.',
#  'He was completely exhausted, completely dehydrated, suffered significant weight loss, somewhere up to 50%.',
#  'I broke one leg and broke the ankle in my other leg',
#  '[B].',
#  "John's mother.",
#  'It took her a few hours to pick enough apples to make dozens of pies.',
#  'the Greek  "to choke"',
#  'No, Larry is one of their best chums',
#  'Nairo Quintana',
#  'Libby Little',
#  'Manhattan',
#  '(iii).',
#  'adapts for film and television',
#  'Repblica Bolivariana de Venezuela',
#  'C,D,and E',
#  'Berlin']

# %%
pred_custom_df=pd.DataFrame(pd.Series(pred_custom,name="pred_custom"))
pred_ft5_df=pd.DataFrame(pd.Series(pred_ft5,name="pred_ft5"))
temp_df=pd.concat([ftrain_data.iloc[psi:pei].reset_index(),train_data.iloc[psi:pei,4].reset_index(),pred_custom_df,pred_ft5_df],axis=1)
temp_df
# pprint(temp_df.iloc[1,0])
# Out:
#     index                                              input  \
# 0    50.0  CHAPTER XL JOY WELL-NIGH INCREDIBLE \n\nThe mi...
# 1    51.0  CHAPTER VIII \n\nA TIME OF WAITING \n\nDinah w...
# 2    52.0  (CNN) -- The grandmother of a missing Maine to...
# 3    53.0  (CNN) -- "I killed that lady," the 10-year-old...
# 4    54.0  CHAPTER XV. SAFE-CONDUCT \n\nAcross the body o...
# 5    55.0  Kate's parents planned a family trip to Europe...
# 6    56.0  Buenos Aires, Argentina (CNN) -- Roberto Sanch...
# 7    57.0  CHAPTER III: Lightfoot Tells How His Antlers G...
# 8    58.0  CHAPTER VIII. \n\nNEW QUARTERS. \n\nUntil near...
# 9    59.0  (CNN) -- Civil rights activist Dorothy Height,...
# 10   60.0  (CNN) -- Cristiano Ronaldo underlined just why...
# 11   61.0  The modern English word green comes from the M...
# 12   62.0  The Cayman Islands ( or ) is an autonomous Bri...
# 13   63.0  A Muslim is someone who follows or practices I...
# 14   64.0  CHAPTER XLI \n\nTHE COLONEL SPEAKS \n\nWrayson...
# 15   65.0  Rio de Janeiro (; ; "River of January"), or si...
# 16   66.0  (EW.com) -- Identity Thief (CinemaScore: B) fa...
# 17   67.0  Once upon a time there was a fish that lived i...
# 18   68.0  CHAPTER XI \n\nBORROWDEAN SHOWS HIS "HAND" \n\...
# 19   69.0  (CNN) -- The stepmother of a missing 10-year-o...
# 20   70.0  New York—often called New York City or the Cit...
# 21   71.0  (CNN) -- A Pakistani Taliban commander who had...
# 22   72.0  The United States Department of State (DOS), o...
# 23   73.0  The Organization of American States, or the OA...
# 24   74.0  CHAPTER I \n\nANDY AND HIS UNCLE \n\n"What be ...
# 25   75.0  Norway ( ; Norwegian: (Bokmål) or (Nynorsk); )...
# 26   76.0  The Most Honourable Order of the Bath (formerl...
# 27   77.0  CHAPTER FORTY-FIVE \n\nIN WHICH TOM PINCH AND ...
# 28   78.0  CHAPTER XI. \n\nIke Watson's Arrival \n\nLet u...
# 29   79.0  Vancouver is a coastal seaport city in Canada,...
# 30   80.0  (CNN) -- The 54-year-old Michigan tree trimmer...
# 31   81.0  (CNN) -- Robert Barchi believed he had much mo...
# 32   82.0  CHAPTER XXIII \n\nDOWN THE STATEN ISLAND SHORE...
# 33   83.0  (CNN) -- A Florida man charged with murder in ...
# 34   84.0  (CNN) -- Rosa Brooks says "keep calm and shut ...
# 35   85.0  A family of four went to the zoo today. The an...
# 36   86.0  Hong Kong (CNN) -- An Australian teenager repo...
# 37   87.0  (CNN) -- He may not have started from the top ...
# 38   88.0  CHAPTER XXII. \n\nSpectre though I be, I am no...
# 39   89.0  (CNN) -- Every day for decades, it was an esse...
# 40   90.0  It was time for Jill to make her famous apple ...
# 41   91.0  Nitrogen is a chemical element with symbol N a...
# 42   92.0  CHAPTER V \n\nGETTING ACQUAINTED \n\n"Dick, we...
# 43   93.0  (CNN) -- Chris Froome conquered Mont Ventoux a...
# 44   94.0  Kabul, Afghanistan (CNN) -- Two aid workers ki...
# 45   95.0  (CNN) -- Patti LaBelle has agreed to pay $100,...
# 46   96.0  Two years into the Syrian conflict, President ...
# 47   97.0  SHANGHAI, China (CNN) -- If it weren't for the...
# 48   98.0  Venezuela, officially the Bolivarian Republic ...
# 49   99.0  My heart went out to Barb Dunn the moment her ...
# 50    NaN                                                NaN
#
#                                           instruction  \
# 0                        What was she suffering from?
# 1                                   Was it light out?
# 2                                        On what day?
# 3                                                Why?
# 4   What did M. de La Tour d'Azyr do after he read...
# 5                 What did she think about the plane?
# 6                   Where did Sandro sell out a show?
# 7                         What kind of animal was he?
# 8                       What did he say they must do?
# 9                           was that report accurate?
# 10                        Who did Bayern Munich play?
# 11               What kind of root does it come from?
# 12  What are the three islands that comprise the C...
# 13                                     Name 2 for me?
# 14  What time did Wrayson keep glancing at the clock?
# 15                               When was it founded?
# 16         How many cast members of it are mentioned?
# 17                      What did the fish want to do?
# 18               What would Mannering's defection be?
# 19                                  Who went missing?
# 20                               is food one of them?
# 21                             Where did this happen?
# 22                 Who is the head of the department?
# 23  Who proposed the idea of an international unio...
# 24                               Who is Andy's Uncle?
# 25                           Who are Norway's allies?
# 26                what were created knights known as?
# 27                                  For what purpose?
# 28         What did he cry when he grabbed the horse?
# 29                        Is it a nice place to live?
# 30                Were they the relatives of the kid?
# 31                            Was it a popular story?
# 32                                    What drew them?
# 33  What did Robin Lemonidis, Michael Dunn's attor...
# 34            did she talk about a social media site?
# 35                      What did the kids need to do?
# 36          Was he in good shape when they found him?
# 37  What happened to Patrick Keung in 2006 that al...
# 38  Was she disappointed that it wasn't who she ex...
# 39          Who was listening to Harvey at his house?
# 40  How long did it take Jill to pick enough apple...
# 41          Where does the name pnictogens come from?
# 42                 Is he just a distant acquaintance?
# 43            Who did the leader fight for 1st place?
# 44                  Who was in charge of the injured?
# 45                                             Where?
# 46                 Has Kerry had to change his story?
# 47                             what about for movies?
# 48  What was the official name change in the new c...
# 49  What did Barb Dunn do when she heard her son's...
# 50                                                NaN
#
#                                                output  index  \
# 0                                               grief   50.0
# 1                                                  no   51.0
# 2                                                  17   52.0
# 3                                   she yelled at him   53.0
# 4                                         replaced it   54.0
# 5                                             was fun   55.0
# 6                               madison square garden   56.0
# 7                                             a Hare.   57.0
# 8                               Change their quarters   58.0
# 9                                                  No   59.0
# 10                                       CSKA Moscow.   60.0
# 11                                           Germanic   61.0
# 12       grand cayman , cayman brac and little cayman   62.0
# 13                                  Abraham and Moses   63.0
# 14                                          twentieth   64.0
# 15                                               1565   65.0
# 16                                              Three   66.0
# 17                                              party   67.0
# 18                                       irremediable   68.0
# 19                                             a girl   69.0
# 20                                                 No   70.0
# 21                          South Waziristan Province   71.0
# 22                                      Rex Tillerson   72.0
# 23                                      simon bolivar   73.0
# 24                                                 Si   74.0
# 25                                            unknown   75.0
# 26                              "Knights of the Bath"   76.0
# 27               to attract his wandering observation   77.0
# 28                                              Whoa!   78.0
# 29                                                yes   79.0
# 30                                            unknown   80.0
# 31                                               Yes.   81.0
# 32                                              alarm   82.0
# 33  he is devastated and horrified by the death of...   83.0
# 34                                                Yes   84.0
# 35                              lean all the way back   85.0
# 36                                                 no   86.0
# 37  broke one leg and broke the ankle in my other leg   87.0
# 38                                              Mabel   88.0
# 39                                            unknown   89.0
# 40                                        a few hours   90.0
# 41                                     from the Greek   91.0
# 42                                                 no   92.0
# 43                                           Quintana   93.0
# 44                                            unknown   94.0
# 45                                          the lobby   95.0
# 46                                                Yes   96.0
# 47                                                yes   97.0
# 48                   Bolivarian Republic of Venezuela   98.0
# 49  my heart went out to barb dunn the moment her ...   99.0
# 50                                                NaN    NaN
#
#                                             span_text  \
# 0                                               grief
# 1                      It is very dark, still, Dinah.
# 2                                                  17
# 3   Kurilla told police he was angry at Novak beca...
# 4                                         replaced it
# 5   She loves to be on planes. The plane ride was fun
# 6                               madison square garden
# 7   Peter jumped and turned to find his big cousin...
# 8                                                 NaN
# 9   \nHeight remains hospitalized, according to Al...
# 10  Bayern Munich's title defence with an emphatic...
# 11                        from the same Germanic root
# 12       grand cayman , cayman brac and little cayman
# 13            many prophets including Abraham, Moses,
# 14                                          twentieth
# 15                                               1565
# 16  We talked a little bit about stars Rooney Mara...
# 17                                              party
# 18        Mannering's defection would be irremediable
# 19          a missing 10-year-old North Carolina girl
# 20                                                NaN
# 21  e was taken into custody in South Waziristan p...
# 22    The current Secretary of State is Rex Tillerson
# 23                                      simon bolivar
# 24                                           Uncle Si
# 25                                            unknown
# 26  The knights so created were known as "Knights ...
# 27               to attract his wandering observation
# 28                                              Whoa!
# 29                 for livability and quality of life
# 30                                            unknown
# 31               it dominated the airwaves for a week
# 32  The alarm had now become general, and by the t...
# 33  he is devastated and horrified by the death of...
# 34  You don't need to keep changing your Facebook ...
# 35                                                NaN
# 36  He was completely exhausted, completely dehydr...
# 37  broke one leg and broke the ankle in my other leg
# 38                                              Mabel
# 39                                            unknown
# 40                                        a few hours
# 41                                     from the Greek
# 42                                                NaN
# 43  Quintana before the Colombian faded and Froome...
# 44                                            unknown
# 45                         wandering around the lobby
# 46  Obama's own administration seems confused as w...
# 47               and adapted for film and television
# 48  This new constitution officially changed the n...
# 49  my heart went out to barb dunn the moment her ...
# 50                                                NaN
#
#                                           pred_custom  \
# 0          health had suffered from grief for Michael
# 1                                                  No
# 2                                         December 17
# 3                               To ask her a question
# 4                                     he was composed
# 5                                          it was fun
# 6                               Madison Square Garden
# 7                                                Hare
# 8                                               leave
# 9                                                  no
# 10                                        CSKA Moscow
# 11                                           Germanic
# 12        Grand Cayman, Cayman Brac and Little Cayman
# 13                       God is eternal, transcendent
# 14                                      What the time
# 15                                   Founded in 1565.
# 16                                                  3
# 17                               give the kid a party
# 18                                       irremediable
# 19                                  Zahra Clare Baker
# 20                                                 no
# 21                          South Waziristan province
# 22                             the Secretary of State
# 23                                       Simón Bolvar
# 24                                                 Si
# 25                                            Finland
# 26                                Knights of the Bath
# 27               to attract his wandering observation
# 28                                              Whoa!
# 29                                                yes
# 30                                                 no
# 31                                                 No
# 32                                    The searchlight
# 33  There are no comparisons to the Trayvon Martin...
# 34                                                yes
# 35                              lean all the way back
# 36                                                 No
# 37  I broke one leg and broke the ankle in my othe...
# 38                                               [B].
# 39                                     John's mother.
# 40                                        a few hours
# 41                              the Greek  "to choke"
# 42                 No, he is one of their best chums.
# 43                                     Nairo Quintana
# 44                                        Afghanistan
# 45                        in the lobby of Trump Place
# 46                                                 No
# 47                                          adapts it
# 48                  Repblica Bolivariana de Venezuela
# 49                                         C,D, and E
# 50                                             Berlin
#
#                                              pred_ft5
# 0                                               Grief
# 1                                                  i.
# 2                                         December 17
# 3                 To ask something to his grandmother
# 4                                     he was composed
# 5                                          it was fun
# 6                               Madison Square Garden
# 7                                           Lightfoot
# 8                                               leave
# 9                                                  i.
# 10                                        CSKA Moscow
# 11                                           Germanic
# 12        Grand Cayman, Cayman Brac and Little Cayman
# 13                                           Shahadah
# 14                                 What the time was?
# 15                 Founded in 1565 by the Portuguese,
# 16                                                  3
# 17                                               (ii)
# 18                                       irremediable
# 19                                  Zahra Clare Baker
# 20                                                 no
# 21                          South Waziristan province
# 22                             the Secretary of State
# 23                                       Simón Bolvar
# 24                                     Josiah Graham,
# 25                                            Finland
# 26                                Knights of the Bath
# 27                      Tom to look past the fountain
# 28                                              Whoa!
# 29  Vancouver is consistently named as one of the ...
# 30                       none are known to be related
# 31                                                A).
# 32                                    The searchlight
# 33  He is devastated and horrified by the death of...
# 34                                                yes
# 35                                                 I.
# 36  He was completely exhausted, completely dehydr...
# 37  I broke one leg and broke the ankle in my othe...
# 38                                               [B].
# 39                                     John's mother.
# 40  It took her a few hours to pick enough apples ...
# 41                              the Greek  "to choke"
# 42               No, Larry is one of their best chums
# 43                                     Nairo Quintana
# 44                                       Libby Little
# 45                                          Manhattan
# 46                                             (iii).
# 47                     adapts for film and television
# 48                  Repblica Bolivariana de Venezuela
# 49                                          C,D,and E
# 50                                             Berlin

# %%
# pred_custom_df=pd.DataFrame(pd.Series(pred_custom,name="pred_custom"))
# pred_ft5_df=pd.DataFrame(pd.Series(pred_ft5,name="pred_ft5"))
pred_ft5_df=pd.read_csv("/home/u131168/mh_one_api/data/sub_ft5.csv")
temp_df=pd.concat([test_data.iloc[:p_count],pred_ft5_df[:p_count]],axis=1)
temp_df
# Out:
#                                                 Story  \
# 0   CHAPTER I \n\nON THE HOUSEBOAT \n\n"Say, Tom, ...
# 1   The Uralic languages (; sometimes called Urali...
# 2   The University of Wisconsin–Madison (also know...
# 3   (CNN) -- The unexpected resignation of David P...
# 4   CHAPTER THIRTY-TWO \n\nTENDER TROUBLES \n\n"Jo...
# 5   The New York Yankees are an American professio...
# 6   South Ossetia () is a partially recognised sta...
# 7   (CNN) -- The megayacht that Steve Jobs commiss...
# 8   CHAPTER XV \n\nNow that Gordon was gone, at an...
# 9   A high-profile murder case involving one of Am...
# 10  CHAPTER VII \n\nTHE END OF THE TERM \n\n"What ...
# 11  (CNN) -- He was the soccer referee known as "g...
# 12  CHAPTER I \n\nTHE BOYS OF OAK HALL \n\n"Hello,...
# 13  JERUSALEM (CNN) -- The world knows her as the ...
# 14  A telescope is an optical instrument that aids...
# 15  CHAPTER XIII \n\nLOST IN THE SNOW \n\n"The ice...
# 16  CHAPTER L \n\nThe Duke's Arguments \n\nThe Duk...
# 17  Joey felt the very first rain drop hit his hat...
# 18  Marietta, Georgia (CNN) -- Whether the prosecu...
# 19  Piedmont ( ; , ; Piedmontese, Occitan and ; ) ...
# 20  (CNN)A teen couple from Kentucky was arrested ...
# 21  Chapter 9 \n\nChivalry or Villainy \n\nFrom he...
# 22  (CNN) -- A former Utah policeman is a suspect ...
# 23  (CNN) -- After months of speculation, one of F...
# 24  The University of Illinois at Urbana–Champaign...
# 25  Saturday Night Live (abbreviated as SNL) is an...
# 26  CHAPTER XXVIII \n\nSPENNIE'S HOUR OF CLEAR VIS...
# 27  Elizabeth I (7 September 1533 – 24 March 1603)...
# 28  East Timor () or Timor-Leste (; Tetum: "Timór ...
# 29  (CNN) -- Two Amish girls, who were apparently ...
# 30  Kiev, Ukraine (CNN) -- Ukraine and Russia plan...
# 31  (CNN) -- Members of the international communit...
# 32  Tristan da Cunha /ˈtrɪstən də ˈkuːnjə/, colloq...
# 33  Singing competition shows like "American Idol"...
# 34  CHAPTER VIII \n\nD'AGUILAR SPEAKS \n\n"Losses?...
# 35  Chapter V. Mohun Appears For The Last Time In ...
# 36  I'd had the piggy bank for a long time. So lon...
# 37  A police cruiser draped in black banners and t...
# 38  The National Aeronautics and Space Administrat...
# 39  Koninklijke Philips N.V. (Koninklijke Philips ...
# 40  CHAPTER LXV - MISS LONGESTAFFE WRITES HOME \n\...
# 41  Chapter VI. -- THE LITTLE DRUMMER. \n\nThis Si...
# 42  CHAPTER THIRTY TWO. \n\nTOUCHES ON LOVE AND ON...
# 43  Tampa () is a major city in, and the county se...
# 44  CHAPTER XIX \n\nA letter, edged with black, an...
# 45  CHAPTER XX. \n\nHOW CAPTAIN USSHER SUCCEEDED. ...
# 46  CHAPTER EIGHTEEN. \n\nANXIOUS TIMES--A SEARCH ...
# 47  The Whigs were a political faction and then a ...
# 48  CHAPTER XVIII \n\nTHE HAND IN THE WATER \n\nSc...
# 49  (CNN) -- "I don't know the ins and outs of his...
#
#                                              Question  \
# 0                                What was Sam's mood?
# 1                                        By how many?
# 2         How many schools and colleges does it have?
# 3                                      What happened?
# 4   Why does Mrs. March not force her children's c...
# 5   When did the team start playing in Yankee Stad...
# 6           Who does Russia not allow to enter there?
# 7   How much money did Steve Jobs commission for t...
# 8   Does he think the reason she gave are conflict...
# 9                             For the murder of whom?
# 10                              Where does Gabe live?
# 11                            Was anyone else caught?
# 12                who was resting on one of the beds?
# 13                                             Where?
# 14                                         What year?
# 15                            What did Hans call Tom?
# 16   What did Lady Cantrip think of Mary's character?
# 17                     What was he doing at the time?
# 18                              Who is the defendant?
# 19                                    Which is first?
# 20                   What had kin of the female done?
# 21                          Who did he hang out with?
# 22                       What was Smiths' profession?
# 23                            How many did they lose?
# 24  How many different things are there for studying?
# 25                      Does it have an abbreviation?
# 26                    Had he stopped smiling by then?
# 27                                        until when?
# 28                       Who did it get freedom from?
# 29                     where were they abducted from?
# 30                                              When?
# 31  What did U.S. Vice President Joe Biden express...
# 32                         Are all of them populated?
# 33  What could Britney Spears do to reignite the l...
# 34  Did he admit knowing about the other man's tro...
# 35                                             Where?
# 36                   Who told her the story about it?
# 37  How long is the investigation into the acciden...
# 38                      Did it lead the Moon landing?
# 39                                             where?
# 40                                         with whom?
# 41                        which one was the lead one?
# 42                             What is he favored by?
# 43  What happened to the native societies when the...
# 44                              How was it decorated?
# 45                          Who left after breakfast?
# 46                         What made Freydissa nicer?
# 47                               When did they start?
# 48                   what kind of blood does he have?
# 49  How many shows were on Noel Gallagher's tour f...
#
#                                                Answer
# 0                                             Anxious
# 1                                         125 million
# 2                                                  20
# 3   David Petraeus remained stoically aloof as a s...
# 4                                   She wants to wait
# 5                                                1923
# 6                                      European Union
# 7                                    100-million-euro
# 8                                                 yes
# 9                                                  __
# 10                                         the school
# 11                                          Wan Daxue
# 12                                             Shadow
# 13  Israel's Chabad movement has set up a fund to ...
# 14                                               1608
# 15                                      a goot feller
# 16                            Mary has great firmness
# 17                            watching out the window
# 18                                 Justin Ross Harris
# 19                                           Piedmont
# 20                               reported her missing
# 21                                      savage beasts
# 22                                          policeman
# 23                                                 44
# 24                                      more than 150
# 25                                                yes
# 26                    ballroom's music had died away.
# 27                                          her death
# 28                                           Portugal
# 29                              a roadside farm stand
# 30                                           Tuesday,
# 31  the Iranian government had suppressed crowds a...
# 32                                        uninhabited
# 33                        showing off her personality
# 34                                                yes
# 35                                              Paris
# 36                                           Her Aunt
# 37                                  could take months
# 38                                               NASA
# 39                                          Amsterdam
# 40                                      Lady Monogram
# 41                         Count Fink von Finkenstein
# 42                                            Fortune
# 43  introduced European diseases which brought the...
# 44                                    By the mourning
# 45                                              Feemy
# 46                          by the sight of the child
# 47                        Between the 1680s and 1850s
# 48                                             Indian
# 49                                                 81

# %%
test_data
# Out:
#                                                    Story  \
# 0      CHAPTER I \n\nON THE HOUSEBOAT \n\n"Say, Tom, ...
# 1      The Uralic languages (; sometimes called Urali...
# 2      The University of Wisconsin–Madison (also know...
# 3      (CNN) -- The unexpected resignation of David P...
# 4      CHAPTER THIRTY-TWO \n\nTENDER TROUBLES \n\n"Jo...
# ...                                                  ...
# 28543  CHAPTER III. \n\n"Nice customs curt'sy to grea...
# 28544  CHAPTER XI. \n\nIn the little dining-room of t...
# 28545  Chapter XXX. \n\n"I shall go on through all et...
# 28546  Chapter XXXIV \n\nViolence \n\n\n\nIt had been...
# 28547  Be home by dinnertime, Eric's mother said as h...
#
#                                                 Question
# 0                                   What was Sam's mood?
# 1                                           By how many?
# 2            How many schools and colleges does it have?
# 3                                         What happened?
# 4      Why does Mrs. March not force her children's c...
# ...                                                  ...
# 28543  Who was the Archbishop of Toledo that was of t...
# 28544                                   Who lived there?
# 28545                                        is he fair?
# 28546              Where was he to stay until this trip?
# 28547                 what reptile did his friend bring?
#
# [28548 rows x 2 columns]

# %%
temList=[0 for i in range(28548-len(res))]
submission_data=pd.Series(res+temList,name="Answer")
submission_data=pd.DataFrame(submission_data)
submission_data.to_csv("/home/u131168/mh_one_api/data/submissionflant5base.csv",index=False)
submission_data
# Out:
#                                                   Answer
# 0                                                Anxious
# 1                                            125 million
# 2                                                     20
# 3      David Petraeus remained stoically aloof as a s...
# 4                                      She wants to wait
# ...                                                  ...
# 28543                                                  0
# 28544                                                  0
# 28545                                                  0
# 28546                                                  0
# 28547                                                  0
#
# [28548 rows x 1 columns]
